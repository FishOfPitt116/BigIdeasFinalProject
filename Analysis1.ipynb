# %%
import pandas as pd
# %matplotlib inline

# %%
treesData = pd.read_csv("PittsburghTrees.csv")

treesData.id = treesData.id.astype(object)
#noData = treesData.loc[treesData["id"] == "-"]



treesGroup = treesData.groupby("neighborhood").count()
#treesGroup.head(50)
sortedTreesGroup = treesGroup.sort_values("common_name", ascending= False)

neighborhoods = []
treeTotals = []


neighCol = sortedTreesGroup.iloc[:, 0]
numbCol = sortedTreesGroup.iloc[:, 4]

#for i in sortedTreesGroup.iterrows():
   # neighborhoods.append(i[0])
   # treeTotals.append(i[1])
    
#neighborhoods
#treeTotals
sortedtreesGroup.head(10)
    #neighborhoods.append(sortedTreesGroup.iloc[[i], [0]])
    #treeTotals.append(sortedTreesGroup.iloc[[i], [4]])
# Out:
#                              id  address_number  street  common_name  \
# neighborhood
# Squirrel Hill South        5073            2590    2590         5073
# Highland Park              2941            1289    1289         2941
# Squirrel Hill North        2083            1801    1801         2083
# South Side Flats           1693            1686    1689         1693
# Shadyside                  1558            1558    1558         1557
# Bloomfield                 1436            1427    1430         1435
# East Liberty               1366            1364    1364         1365
# Point Breeze               1316            1123    1123         1316
# Perry North                1007             401     402         1007
# Central Business District  1002            1002    1002         1002
#
#                            scientific_name  height  width  \
# neighborhood
# Squirrel Hill South                   5073    4938   4934
# Highland Park                         2941    2769   2768
# ...
